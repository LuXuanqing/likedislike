# %%
import imageio
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %%
reader = imageio.get_reader('<video0>')

# %%
while True:
    frame = reader.get_next_data()
    plt.imshow(frame)
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-72240a95394d> in <module>()
#       2     frame = reader.get_next_data()
#       3     plt.imshow(frame)
# ----> 4     time.sleep(2)
#
# KeyboardInterrupt:
