# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
im1 = Image.open('test/good.jpg')

# %%
im1 = im1.resize((240,320))

# %%
im1.size
# Out:
# (240, 320)

# %%
im1.save('good.jpg')

# %%
im2 = Image.open('test/bad.jpg')

# %%
im2 = im2.resize((240,320))

# %%
im2.save('bad.jpg')

# %%
from keras.models import load_model
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model('my_model.h5')

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=240x320 at 0x1BAFF493A20>

# %%
x1 = np.asarray(im1)

# %%
x1 = np.expand_dims(x1, 0)

# %%
x1.shape
# Out:
# (1, 320, 240, 3)

# %%
model.predict(x1)
# Out:
# array([[1.]], dtype=float32)

# %%
x2 = np.expand_dims(np.asarray(im2),0)

# %%
x2.shape
# Out:
# (1, 320, 240, 3)

# %%
model.predict(x2)
# Out:
# array([[0.]], dtype=float32)

# %%
im2
# Out:
# <PIL.Image.Image image mode=RGB size=240x320 at 0x1BAFF249278>

# %%
def ka(H,W):
    cap = cv2.VideoCapture(0)
    while(True):
        # Capture frame-by-frame
        ret, frame = cap.read()
        # Display the resulting frame
        cv2.imshow('frame',gray)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break 
    cv.destroyAllWindows()
